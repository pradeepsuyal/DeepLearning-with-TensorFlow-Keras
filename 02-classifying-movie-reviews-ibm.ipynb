# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import imdb
from tensorflow.keras import models
from tensorflow.keras import layers

(train_data, train_labels), (test_data, test_labels) = imdb.load_data(num_words=10000)

# %% [markdown]
# The argument num_words=10000 means you’ll only keep the top 10,000 most frequently occurring words in the training data. Rare words will be discarded. This allows
# you to work with vector data of manageable size.

# %% [markdown]
# Because you’re restricting yourself to the top 10,000 most frequent words, no word
# index will exceed 10,000:

# %%
max([max(sequence) for sequence in train_data])
# Out:
# 9999

# %% [markdown]
# here’s how we can quickly decode one of these reviews back to English
# words

# %%
word_index = imdb.get_word_index()
reverse_word_index = dict([(key, val) for (key, val) in word_index.items()])
decoded_review = ' '.join([reverse_word_index.get(i-3,'?') for i in train_data[0]])

# %%
# encoding data
def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))
    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1.
    return results

x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)

# %%
x_train[0]
# Out:
# array([0., 1., 1., ..., 0., 0., 0.])

# %%
y_train = np.asarray(train_labels).astype('float32')
y_test = np.asarray(test_labels).astype('float32')

# %% [markdown]
# Building network

# %%
from tensorflow.keras import models
from tensorflow.keras import layers

model = models.Sequential()
model.add(layers.Dense(16, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(16, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))
# Out:
# 2023-01-04 15:11:46.857708: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-04 15:11:46.858668: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-04 15:11:46.867546: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-04 15:11:46.868460: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-04 15:11:46.869277: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-04 15:11:46.870056: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-04 15:11:46.872272: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-04 15:11:47.080436: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-04 15:11:47.081420: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-04 15:11:47.082391: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-04 15:11:47.083230: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-04 15:11:47.084012: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-04 15:11:47.084760: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-04 15:11:48.302854: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-04 15:11:48.303782: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-04 15:11:48.304574: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-04 15:11:48.305301: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-04 15:11:48.306038: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-04 15:11:48.306764: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13789 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# 2023-01-04 15:11:48.307229: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2023-01-04 15:11:48.307997: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13789 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy',
              metrics=['acc'])

# %% [markdown]
# creating validation dataset

# %%
x_val = x_train[:10000]
partial_x_train = x_train[10000:]

# %%
y_val = y_train[:10000]
partial_y_train = y_train[10000:]

# %%
history = model.fit(partial_x_train, partial_y_train, epochs=20,
                    batch_size=512, validation_data=(x_val, y_val))
# Out:
# 2023-01-04 15:13:51.018565: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 600000000 exceeds 10% of free system memory.
# 2023-01-04 15:13:51.725592: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 600000000 exceeds 10% of free system memory.
# 2023-01-04 15:13:52.234937: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/20
# 30/30 [==============================] - 3s 70ms/step - loss: 0.5067 - acc: 0.7907 - val_loss: 0.3800 - val_acc: 0.8675
# Epoch 2/20
# 30/30 [==============================] - 1s 21ms/step - loss: 0.2979 - acc: 0.9013 - val_loss: 0.3108 - val_acc: 0.8809
# Epoch 3/20
# 30/30 [==============================] - 1s 21ms/step - loss: 0.2169 - acc: 0.9289 - val_loss: 0.2906 - val_acc: 0.8832
# Epoch 4/20
# 30/30 [==============================] - 1s 25ms/step - loss: 0.1718 - acc: 0.9423 - val_loss: 0.3102 - val_acc: 0.8764
# Epoch 5/20
# 30/30 [==============================] - 1s 30ms/step - loss: 0.1351 - acc: 0.9587 - val_loss: 0.3027 - val_acc: 0.8840
# Epoch 6/20
# 30/30 [==============================] - 1s 22ms/step - loss: 0.1142 - acc: 0.9632 - val_loss: 0.2978 - val_acc: 0.8867
# Epoch 7/20
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0958 - acc: 0.9711 - val_loss: 0.3157 - val_acc: 0.8845
# Epoch 8/20
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0769 - acc: 0.9781 - val_loss: 0.3403 - val_acc: 0.8822
# Epoch 9/20
# 30/30 [==============================] - 1s 19ms/step - loss: 0.0636 - acc: 0.9842 - val_loss: 0.3736 - val_acc: 0.8805
# Epoch 10/20
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0505 - acc: 0.9877 - val_loss: 0.4116 - val_acc: 0.8688
# Epoch 11/20
# 30/30 [==============================] - 1s 20ms/step - loss: 0.0435 - acc: 0.9893 - val_loss: 0.4205 - val_acc: 0.8757
# Epoch 12/20
# 30/30 [==============================] - 1s 18ms/step - loss: 0.0364 - acc: 0.9913 - val_loss: 0.4522 - val_acc: 0.8755
# Epoch 13/20
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0260 - acc: 0.9953 - val_loss: 0.4989 - val_acc: 0.8653
# Epoch 14/20
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0222 - acc: 0.9961 - val_loss: 0.5213 - val_acc: 0.8718
# Epoch 15/20
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0184 - acc: 0.9964 - val_loss: 0.5520 - val_acc: 0.8703
# Epoch 16/20
# 30/30 [==============================] - 1s 24ms/step - loss: 0.0150 - acc: 0.9977 - val_loss: 0.5884 - val_acc: 0.8675
# Epoch 17/20
# 30/30 [==============================] - 1s 22ms/step - loss: 0.0097 - acc: 0.9993 - val_loss: 0.6828 - val_acc: 0.8632
# Epoch 18/20
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0099 - acc: 0.9988 - val_loss: 0.6623 - val_acc: 0.8675
# Epoch 19/20
# 30/30 [==============================] - 1s 23ms/step - loss: 0.0050 - acc: 0.9999 - val_loss: 0.6989 - val_acc: 0.8642
# Epoch 20/20
# 30/30 [==============================] - 1s 21ms/step - loss: 0.0062 - acc: 0.9991 - val_loss: 0.7323 - val_acc: 0.8648

# %%
history_dict = history.history
history_dict.keys()
# Out:
# dict_keys(['loss', 'acc', 'val_loss', 'val_acc'])

# %%
model.fit(x_train, y_train, epochs=4, batch_size=512)
results = model.evaluate(x_test, y_test)
# Out:
# 2023-01-04 15:18:36.626954: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 1000000000 exceeds 10% of free system memory.
# 2023-01-04 15:18:37.780454: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 1000000000 exceeds 10% of free system memory.
# Epoch 1/4
# 49/49 [==============================] - 1s 13ms/step - loss: 0.2237 - acc: 0.9456
# Epoch 2/4
# 49/49 [==============================] - 1s 13ms/step - loss: 0.1378 - acc: 0.9596
# Epoch 3/4
# 49/49 [==============================] - 1s 12ms/step - loss: 0.1157 - acc: 0.9651
# Epoch 4/4
# 49/49 [==============================] - 1s 15ms/step - loss: 0.0922 - acc: 0.9710
# 2023-01-04 15:18:41.928693: W tensorflow/core/framework/cpu_allocator_impl.cc:80] Allocation of 1000000000 exceeds 10% of free system memory.
# 782/782 [==============================] - 2s 2ms/step - loss: 0.4747 - acc: 0.8594
